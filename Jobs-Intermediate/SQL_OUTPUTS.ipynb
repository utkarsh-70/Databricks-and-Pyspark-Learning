# %% [markdown]
# ### This file will hold the output of the sql file query

# %%
dbutils.widgets.text("sql_output","")

# %%
dbutils.widgets.get("sql_output")
