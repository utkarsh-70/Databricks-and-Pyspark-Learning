# %% [markdown]
# ### In this notebook we will be using the notebook X output using the jobs

# %%
dbutils.widgets.text("records_processed","")

# %%
d=dbutils.widgets.get("records_processed")
display(d)
