# %%
df=spark.createDataFrame([('James',1),('Anna',2),('Julia',3)],['name','age'])
display(df)

# %%
records_count=df.count()
display(records_count)

# %%
dbutils.jobs.taskValues.set("total_records", records_count)
